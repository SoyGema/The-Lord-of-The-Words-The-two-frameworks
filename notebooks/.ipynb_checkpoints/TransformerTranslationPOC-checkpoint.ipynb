# %%
# !pip install transformers datasets evaluate sacrebleu
# !pip install 'huggingface_hub[tensorflow]'
# !pip install huggingface_hub
# !pip install tensorflow
# Out:
# Requirement already satisfied: transformers in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (4.29.2)
# Requirement already satisfied: datasets in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: evaluate in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: sacrebleu in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (2.3.1)
# Requirement already satisfied: filelock in /Users/gema/miniconda3/lib/python3.10/site-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /Users/gema/miniconda3/lib/python3.10/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from transformers) (2023.5.5)
# Requirement already satisfied: requests in /Users/gema/miniconda3/lib/python3.10/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/gema/miniconda3/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from datasets) (12.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: xxhash in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from datasets) (2023.5.0)
# Requirement already satisfied: aiohttp in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from datasets) (3.8.4)
# Requirement already satisfied: responses<0.19 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: portalocker in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from sacrebleu) (2.7.0)
# Requirement already satisfied: tabulate>=0.8.9 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: colorama in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /Users/gema/miniconda3/lib/python3.10/site-packages (from sacrebleu) (4.9.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/gema/miniconda3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/gema/miniconda3/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/gema/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: huggingface_hub[tensorflow] in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (0.14.1)
# Requirement already satisfied: filelock in /Users/gema/miniconda3/lib/python3.10/site-packages (from huggingface_hub[tensorflow]) (3.12.0)
# Requirement already satisfied: fsspec in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from huggingface_hub[tensorflow]) (2023.5.0)
# Requirement already satisfied: requests in /Users/gema/miniconda3/lib/python3.10/site-packages (from huggingface_hub[tensorflow]) (2.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from huggingface_hub[tensorflow]) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from huggingface_hub[tensorflow]) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/gema/miniconda3/lib/python3.10/site-packages (from huggingface_hub[tensorflow]) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /Users/gema/miniconda3/lib/python3.10/site-packages (from huggingface_hub[tensorflow]) (23.0)
# Requirement already satisfied: tensorflow in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from huggingface_hub[tensorflow]) (2.13.0rc1)
# Requirement already satisfied: pydot in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from huggingface_hub[tensorflow]) (1.4.2)
# Requirement already satisfied: graphviz in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from huggingface_hub[tensorflow]) (0.20.1)
# Requirement already satisfied: pyparsing>=2.1.4 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from pydot->huggingface_hub[tensorflow]) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests->huggingface_hub[tensorflow]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests->huggingface_hub[tensorflow]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests->huggingface_hub[tensorflow]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests->huggingface_hub[tensorflow]) (2023.5.7)
# Requirement already satisfied: tensorflow-macos==2.13.0-rc1 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from tensorflow->huggingface_hub[tensorflow]) (2.13.0rc1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (3.6.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (16.0.0)
# Requirement already satisfied: numpy>=1.22 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (4.23.2)
# Requirement already satisfied: setuptools in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (1.48.2)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0rc0 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (2.13.0rc0)
# Requirement already satisfied: keras<2.14,>=2.13.1rc0 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (2.13.1rc0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (2.19.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (2.3.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/gema/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (2.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/gema/miniconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow->huggingface_hub[tensorflow]) (3.2.2)
# Requirement already satisfied: huggingface_hub in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (0.14.1)
# Requirement already satisfied: filelock in /Users/gema/miniconda3/lib/python3.10/site-packages (from huggingface_hub) (3.12.0)
# Requirement already satisfied: fsspec in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from huggingface_hub) (2023.5.0)
# Requirement already satisfied: requests in /Users/gema/miniconda3/lib/python3.10/site-packages (from huggingface_hub) (2.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/gema/miniconda3/lib/python3.10/site-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /Users/gema/miniconda3/lib/python3.10/site-packages (from huggingface_hub) (23.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests->huggingface_hub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests->huggingface_hub) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests->huggingface_hub) (2023.5.7)
# Requirement already satisfied: tensorflow in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (2.13.0rc1)
# Requirement already satisfied: tensorflow-macos==2.13.0-rc1 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from tensorflow) (2.13.0rc1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (3.6.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (16.0.0)
# Requirement already satisfied: numpy>=1.22 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (4.23.2)
# Requirement already satisfied: setuptools in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (1.48.2)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0rc0 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.13.0rc0)
# Requirement already satisfied: keras<2.14,>=2.13.1rc0 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from tensorflow-macos==2.13.0-rc1->tensorflow) (2.13.1rc0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/gema/Documents/The-Lord-of-The-Words-The-two-frameworks/.venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0-rc1->tensorflow) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.19.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.3.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/gema/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (1.26.15)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/gema/miniconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/gema/miniconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/gema/miniconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0-rc1->tensorflow) (3.2.2)

# %%
import tensorflow as tf
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# GPU is available

# %%
from huggingface_hub import notebook_login
from datasets import load_dataset
from transformers import AutoTokenizer , DataCollatorForSeq2Seq , AdamWeightDecay , TFAutoModelForSeq2SeqLM
import evaluate
import numpy as np
from transformers import DataCollatorForSeq2Seq
import numpy as np
from transformers import AdamWeightDecay
from transformers import TFAutoModelForSeq2SeqLM
import tensorflow as tf
from transformers.keras_callbacks import KerasMetricCallback
from transformers.keras_callbacks import PushToHubCallback

# %%
notebook_login()

# %%
def load_dataset_huggin(argument):
  "Load the subset from datasets library"
  books = load_dataset("opus_books", argument)
  return books

# %%
english_french = load_dataset_huggin("en-fr")
english_hungarian = load_dataset_huggin("en-hu")
english_netherlands = load_dataset_huggin("en-nl")
english_russian = load_dataset_huggin("en-ru")
english_polish = load_dataset_huggin("en-pl")

# %%
### We can select another languages to translate them, we based this on another languages that 
### have more rows so the finetunning makes more sense

# %%
def split_train_test(argument):
  "Load the subset from datasets library"
  books = argument["train"].train_test_split(test_size=0.2)
  return books

# %%
books = split_train_test(english_french)

# %%
books["train"][0]

# %%
checkpoint = "t5-small"

# %%
def load_tokenizer():
  "Load the tokenizer to process the language pairs"
  checkpoint = "t5-small"
  tokenizer = AutoTokenizer.from_pretrained(checkpoint)
  return tokenizer

tokenizer = load_tokenizer()

# %%
source_lang = "en"
target_lang = "fr"
prefix = "translate English to French:"

# %%
def preprocess_function(examples):
    inputs = [prefix + example[source_lang] for example in examples["translation"]]
    targets = [example[target_lang] for example in examples["translation"]]
    model_inputs = tokenizer(inputs, text_target=targets, max_length=128, truncation=True)
    return model_inputs

# %%
tokenized_books = books.map(preprocess_function, batched=True)

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint, return_tensors="tf")

# %%
metric = evaluate.load("sacrebleu")

# %%
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]

    return preds, labels

# %%
def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}

    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    return result

# %%
optimizer = AdamWeightDecay(learning_rate=2e-5, weight_decay_rate=0.01)
model = TFAutoModelForSeq2SeqLM.from_pretrained(checkpoint)

# %%
tf_train_set = model.prepare_tf_dataset(
    tokenized_books["train"],
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

# %%
tf_test_set = model.prepare_tf_dataset(
    tokenized_books["test"],
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)

# %%
model.compile(optimizer=optimizer)

# %%
## Future, create validation dataset

metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_test_set)

# %%
push_to_hub_callback = PushToHubCallback(
    output_dir="my_awesome_opus_books_model",
    tokenizer=tokenizer,
)

# %%
callbacks = [metric_callback, push_to_hub_callback]

# %%
model.fit(x=tf_train_set, validation_data=tf_test_set, epochs=3, callbacks=callbacks)

# %%
text = "translate English to French: Legumes share resources with nitrogen-fixing bacteria."

# %%
from transformers import pipeline

# %%
translator = pipeline("translation", model="my_awesome_opus_books_model")

# %%
translator(text)
